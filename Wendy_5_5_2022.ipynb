# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import cross_validate
from sklearn.preprocessing import PolynomialFeatures

# %% [markdown]
# ### Data Cleaning

# %%
df = pd.read_csv('C:/Users/jul/Desktop/MA415/high_diamond_ranked_10min.csv')
df.head(3)
# Out:
#        gameId  blueWins  blueWardsPlaced  blueWardsDestroyed  blueFirstBlood  \
# 0  4519157822         0               28                   2               1
# 1  4523371949         0               12                   1               0
# 2  4521474530         0               15                   0               0
#
#    blueKills  blueDeaths  blueAssists  blueEliteMonsters  blueDragons  ...  \
# 0          9           6           11                  0            0  ...
# 1          5           5            5                  0            0  ...
# 2          7          11            4                  1            1  ...
#
#    redTowersDestroyed  redTotalGold  redAvgLevel  redTotalExperience  \
# 0                   0         16567          6.8               17047
# 1                   1         17620          6.8               17438
# 2                   0         17285          6.8               17254
#
#    redTotalMinionsKilled  redTotalJungleMinionsKilled  redGoldDiff  \
# 0                    197                           55         -643
# 1                    240                           52         2908
# 2                    203                           28         1172
#
#    redExperienceDiff  redCSPerMin  redGoldPerMin
# 0                  8         19.7         1656.7
# 1               1173         24.0         1762.0
# 2               1033         20.3         1728.5
#
# [3 rows x 40 columns]

# %%
df.shape    # 9879 rows and 40 columns in the dataset
# Out:
# (9879, 40)

# %%
df = df.drop(df.columns[0], axis = 1)    # drop the 'gameId' column
df.head(3)
# Out:
#    blueWins  blueWardsPlaced  blueWardsDestroyed  blueFirstBlood  blueKills  \
# 0         0               28                   2               1          9
# 1         0               12                   1               0          5
# 2         0               15                   0               0          7
#
#    blueDeaths  blueAssists  blueEliteMonsters  blueDragons  blueHeralds  ...  \
# 0           6           11                  0            0            0  ...
# 1           5            5                  0            0            0  ...
# 2          11            4                  1            1            0  ...
#
#    redTowersDestroyed  redTotalGold  redAvgLevel  redTotalExperience  \
# 0                   0         16567          6.8               17047
# 1                   1         17620          6.8               17438
# 2                   0         17285          6.8               17254
#
#    redTotalMinionsKilled  redTotalJungleMinionsKilled  redGoldDiff  \
# 0                    197                           55         -643
# 1                    240                           52         2908
# 2                    203                           28         1172
#
#    redExperienceDiff  redCSPerMin  redGoldPerMin
# 0                  8         19.7         1656.7
# 1               1173         24.0         1762.0
# 2               1033         20.3         1728.5
#
# [3 rows x 39 columns]

# %%
df.columns    # all features in the dataset
# Out:
# Index(['blueWins', 'blueWardsPlaced', 'blueWardsDestroyed', 'blueFirstBlood',
#        'blueKills', 'blueDeaths', 'blueAssists', 'blueEliteMonsters',
#        'blueDragons', 'blueHeralds', 'blueTowersDestroyed', 'blueTotalGold',
#        'blueAvgLevel', 'blueTotalExperience', 'blueTotalMinionsKilled',
#        'blueTotalJungleMinionsKilled', 'blueGoldDiff', 'blueExperienceDiff',
#        'blueCSPerMin', 'blueGoldPerMin', 'redWardsPlaced', 'redWardsDestroyed',
#        'redFirstBlood', 'redKills', 'redDeaths', 'redAssists',
#        'redEliteMonsters', 'redDragons', 'redHeralds', 'redTowersDestroyed',
#        'redTotalGold', 'redAvgLevel', 'redTotalExperience',
#        'redTotalMinionsKilled', 'redTotalJungleMinionsKilled', 'redGoldDiff',
#        'redExperienceDiff', 'redCSPerMin', 'redGoldPerMin'],
#       dtype='object')

# %%
# matplotlib histogram of the feature 'blueWardsPlaced'
plt.hist(df['blueWardsPlaced'], color = 'salmon', edgecolor = 'black',
         bins = int(150/5))
# Out:
# (array([1.534e+03, 6.238e+03, 4.800e+02, 4.120e+02, 5.410e+02, 1.900e+02,
#         1.220e+02, 5.100e+01, 4.900e+01, 8.300e+01, 6.300e+01, 1.000e+01,
#         2.600e+01, 8.000e+00, 1.800e+01, 9.000e+00, 1.300e+01, 1.400e+01,
#         6.000e+00, 4.000e+00, 1.000e+00, 1.000e+00, 1.000e+00, 1.000e+00,
#         2.000e+00, 0.000e+00, 1.000e+00, 0.000e+00, 0.000e+00, 1.000e+00]),
#  array([  5.        ,  13.16666667,  21.33333333,  29.5       ,
#          37.66666667,  45.83333333,  54.        ,  62.16666667,
#          70.33333333,  78.5       ,  86.66666667,  94.83333333,
#         103.        , 111.16666667, 119.33333333, 127.5       ,
#         135.66666667, 143.83333333, 152.        , 160.16666667,
#         168.33333333, 176.5       , 184.66666667, 192.83333333,
#         201.        , 209.16666667, 217.33333333, 225.5       ,
#         233.66666667, 241.83333333, 250.        ]),
#  <BarContainer object of 30 artists>)

# %%
bwp = df['blueWardsPlaced'] 
rwp = df['redWardsPlaced']
# 90% confidence interval
print(bwp.quantile([0.05, 0.95]).T.round(2))
print(rwp.quantile([0.05, 0.95]).T.round(2))
# Out:
# 0.05    12.0
# 0.95    53.0
# Name: blueWardsPlaced, dtype: float64
# 0.05    12.0
# 0.95    53.0
# Name: redWardsPlaced, dtype: float64

# %%
df = df[df['blueWardsPlaced'] <= 50]  # drop the edge cases, wards placed > 50
df = df[df['redWardsPlaced'] <= 50]
df.shape
# Out:
# (8780, 39)

# %%
df.columns
# Out:
# Index(['blueWins', 'blueWardsPlaced', 'blueWardsDestroyed', 'blueFirstBlood',
#        'blueKills', 'blueDeaths', 'blueAssists', 'blueEliteMonsters',
#        'blueDragons', 'blueHeralds', 'blueTowersDestroyed', 'blueTotalGold',
#        'blueAvgLevel', 'blueTotalExperience', 'blueTotalMinionsKilled',
#        'blueTotalJungleMinionsKilled', 'blueGoldDiff', 'blueExperienceDiff',
#        'blueCSPerMin', 'blueGoldPerMin', 'redWardsPlaced', 'redWardsDestroyed',
#        'redFirstBlood', 'redKills', 'redDeaths', 'redAssists',
#        'redEliteMonsters', 'redDragons', 'redHeralds', 'redTowersDestroyed',
#        'redTotalGold', 'redAvgLevel', 'redTotalExperience',
#        'redTotalMinionsKilled', 'redTotalJungleMinionsKilled', 'redGoldDiff',
#        'redExperienceDiff', 'redCSPerMin', 'redGoldPerMin'],
#       dtype='object')

# %%
# drop the dependent features
df = df.drop(['blueEliteMonsters', 'blueGoldPerMin', 'redFirstBlood', 'redKills',
              'redDeaths', 'redEliteMonsters', 'redGoldDiff', 'redGoldPerMin'], axis = 1)
df.shape
# Out:
# (8780, 31)

# %% [markdown]
# ### KNN Classifier

# %%
(train, test) = train_test_split(df, train_size = 0.8, test_size=0.2, shuffle = True, stratify = df.blueWins, random_state = 0)
print(train['blueWins'].value_counts())
print(test['blueWins'].value_counts())
# Out:
# 1    3528
# 0    3496
# Name: blueWins, dtype: int64
# 1    882
# 0    874
# Name: blueWins, dtype: int64

# %%
# baseline error rate on the training set
round(3496/(3528 + 3496), 3)
# Out:
# 0.498

# %%
# baseline error rate on the test set
round(874/(882 + 874), 3)
# Out:
# 0.498

# %%
X_train = train.iloc[:, 1:]
X_test = test.iloc[:, 1:]
y_train = train.iloc[:, 0]
y_test = test.iloc[:, 0]

# %%
# Scaling
scaler = StandardScaler()
scaler.fit(X_train)
X_train = scaler.transform(X_train)
X_test = scaler.transform(X_test)

# %%
# cross Validation
knn = KNeighborsClassifier()
K = np.arange(100) + 1
grid = {"n_neighbors": K}
grid

knnCV = GridSearchCV(knn, param_grid=grid, return_train_score=True, n_jobs=-1)

knnCV.fit(X_train, y_train)

print(f'The best params is {knnCV.best_params_}, and the best valid score is {knnCV.best_score_}')
# Out:
# The best params is {'n_neighbors': 72}, and the best valid score is 0.7307779501373808

# %% [markdown]
# ### Logistic Regression (Without Feature Engineering)

# %%
X = df.drop('blueWins', axis = 1)
y = df.blueWins

# %%
# cross-validation
lgr = LogisticRegression()

scores = cross_validate(lgr, X, y, return_train_score = True)
R2_train = scores['train_score'].mean()
R2_valid = scores['test_score'].mean()

print('train R2', R2_train.round(3))
print('validation R2', R2_valid.round(3))
# Out:
# train R2 0.732
# validation R2 0.733

# %% [markdown]
# ### Feature Importance

# %%
lgr = LogisticRegression()

feature = []
R2_train = []
R2_valid = []

for k in range(X.shape[1]):
    feature.append(X.columns[k])
    x = X.iloc[:,k]
    R2_valid_scores =  cross_validate(lgr, x.values.reshape(-1,1), y)['test_score']
    R2_valid.append(R2_valid_scores.mean())
    lgr.fit(x.values.reshape(-1,1), y)
    R2_train.append(lgr.score(x.values.reshape(-1,1),y))

# %%
# looking at R-squared value for each feature
results = pd.DataFrame()
results['feature'] = feature
results['train R2'] = R2_train
results['valid R2'] = R2_valid
results.sort_values('valid R2', ascending = False)
# Out:
#                          feature  train R2  valid R2
# 14                  blueGoldDiff  0.725513  0.725513
# 15            blueExperienceDiff  0.715034  0.715034
# 28             redExperienceDiff  0.715034  0.715034
# 24                   redAvgLevel  0.650228  0.650228
# 10                  blueAvgLevel  0.646925  0.646925
# 4                     blueDeaths  0.641230  0.641230
# 3                      blueKills  0.634169  0.634169
# 5                    blueAssists  0.614579  0.614579
# 19                    redAssists  0.611390  0.611390
# 2                 blueFirstBlood  0.602164  0.602164
# 20                    redDragons  0.601708  0.601708
# 6                    blueDragons  0.600683  0.600683
# 16                  blueCSPerMin  0.594077  0.594077
# 12        blueTotalMinionsKilled  0.594077  0.594077
# 26         redTotalMinionsKilled  0.589636  0.590205
# 29                   redCSPerMin  0.589636  0.590205
# 13  blueTotalJungleMinionsKilled  0.548633  0.548633
# 27   redTotalJungleMinionsKilled  0.546014  0.546014
# 21                    redHeralds  0.536219  0.536219
# 7                    blueHeralds  0.535649  0.535649
# 18             redWardsDestroyed  0.533371  0.533371
# 22            redTowersDestroyed  0.523690  0.523690
# 8            blueTowersDestroyed  0.522210  0.522210
# 0                blueWardsPlaced  0.519476  0.520729
# 1             blueWardsDestroyed  0.515034  0.515034
# 17                redWardsPlaced  0.512984  0.512870
# 11           blueTotalExperience  0.502278  0.502278
# 9                  blueTotalGold  0.502278  0.502278
# 23                  redTotalGold  0.497722  0.497722
# 25            redTotalExperience  0.497722  0.497722

# %% [markdown]
# ### Feature Engineering

# %%
# engineer training set polynomial features
poly = PolynomialFeatures(2, interaction_only=False, include_bias = False)
Xe_train = poly.fit_transform(X_train)
col = poly.get_feature_names_out(X.columns)
Xe_train = pd.DataFrame(Xe_train, columns=col)
print('             features shape =', X_train.shape)
print('features (engineered) shape =', Xe_train.shape)
# Out:
#              features shape = (7024, 30)
# features (engineered) shape = (7024, 495)

# %%
# engineer test set polynomial features
poly = PolynomialFeatures(2, interaction_only=False, include_bias=False)
Xe_test = poly.fit_transform(X_test)
col = poly.get_feature_names_out(X.columns)
Xe_test = pd.DataFrame(Xe_test, columns=col)
print('             features shape =', X_test.shape)
print('features (engineered) shape =', Xe_test.shape)
# Out:
#              features shape = (1756, 30)
# features (engineered) shape = (1756, 495)

# %%
# standardize features and convert back to dataframe
stnd = StandardScaler()
stnd.fit(Xe_train)
Xe_train = pd.DataFrame(stnd.transform(Xe_train),
                                columns = Xe_train.columns)
Xe_test  = pd.DataFrame(stnd.transform(Xe_test),
                                columns = Xe_test.columns)

# %%
Xe_train.head(3)
# Out:
#    blueWardsPlaced  blueWardsDestroyed  blueFirstBlood  blueKills  blueDeaths  \
# 0         2.763177           -0.377239        0.990647   1.261417    1.679639
# 1        -0.712367           -0.845471        0.990647   0.264508   -0.738011
# 2        -0.339987            1.027458       -1.009441  -0.732401    0.643504
#
#    blueAssists  blueDragons  blueHeralds  blueTowersDestroyed  blueTotalGold  \
# 0     1.816559     1.323357    -0.475215            -0.205341       1.653898
# 1    -0.158445     1.323357     2.104312            -0.205341       0.483383
# 2    -0.652195    -0.755654     2.104312            -0.205341      -0.481653
#
#    ...  redTotalMinionsKilled^2  \
# 0  ...                 0.114249
# 1  ...                 1.088894
# 2  ...                 0.349999
#
#    redTotalMinionsKilled redTotalJungleMinionsKilled  \
# 0                                          -1.646450
# 1                                          -0.123522
# 2                                          -0.811775
#
#    redTotalMinionsKilled redExperienceDiff  redTotalMinionsKilled redCSPerMin  \
# 0                                -0.050886                           0.114249
# 1                                -0.556562                           1.088894
# 2                                 0.309474                           0.349999
#
#    redTotalJungleMinionsKilled^2  \
# 0                      -1.651292
# 1                      -0.654364
# 2                      -1.052573
#
#    redTotalJungleMinionsKilled redExperienceDiff  \
# 0                                      -0.064212
# 1                                      -0.450779
# 2                                       0.199761
#
#    redTotalJungleMinionsKilled redCSPerMin  redExperienceDiff^2  \
# 0                                -1.646450            -0.655071
# 1                                -0.123522            -0.526561
# 2                                -0.811775            -0.573380
#
#    redExperienceDiff redCSPerMin  redCSPerMin^2
# 0                      -0.050886       0.114249
# 1                      -0.556562       1.088894
# 2                       0.309474       0.349999
#
# [3 rows x 495 columns]

# %% [markdown]
# ### Feature Selection

# %%
# create bias column
Xe_train['bias'] = 1
Xe_test['bias']  = 1

# %%
def SelectFeature(model,candidates,X,y):
    N = len(candidates)
    R2 = np.zeros(N)
    for k in range(N):   
        model_k = model.copy()
        model_k.append(candidates[k])
        cv_results = cross_validate(lgr, X[model_k], y, n_jobs=-1)
        R2[k] = cv_results['test_score'].mean()
    R2_max   = R2.max()
    selected = candidates[R2.argmax()] 
    return (selected,R2_max)

# %%
# forward feature selection
model      = ['bias']
candidates = list(Xe_train.columns)
candidates.remove('bias')
R2 = []
lgr = LogisticRegression(fit_intercept=False)
cv_results = cross_validate(lgr,
                            Xe_train[model].values.reshape(-1,1),
                            y_train)
R2.append(cv_results['test_score'].mean())

while (len(candidates) > 0):
    print('candidates left:', len(candidates), end='')
    (selected, R2_max) = SelectFeature(model, candidates,
                                      Xe_train,
                                      y_train)
    candidates.remove(selected)
    model.append(selected)
    R2.append(R2_max)
    print('  selected:',selected)

results = pd.DataFrame()
results['feature added'] = model
results['valid R2'] = R2

ix = results['valid R2'].idxmax()
print()
print('use features 0 to',ix,end='')
R2_max = results['valid R2'].max()
print('    maximum validation R2 =',round(R2_max,3))
model_opt = model[0:ix+1]

## It's running...
# Out:
# candidates left: 495  selected: blueTotalExperience blueGoldDiff
# candidates left: 494  selected: blueTotalJungleMinionsKilled redTotalMinionsKilled
# candidates left: 493  selected: blueDragons blueHeralds
# candidates left: 492  selected: blueTotalGold blueExperienceDiff
# candidates left: 491  selected: blueTotalJungleMinionsKilled redDragons
# candidates left: 490  selected: blueDragons blueTotalMinionsKilled
# candidates left: 489  selected: blueWardsDestroyed redAssists
# candidates left: 488  selected: blueTotalJungleMinionsKilled redHeralds
# candidates left: 487  selected: blueDeaths blueHeralds
# candidates left: 486  selected: blueWardsPlaced blueDragons
# candidates left: 485  selected: blueHeralds redAssists
# candidates left: 484  selected: blueTotalGold redWardsPlaced
# candidates left: 483  selected: blueTotalJungleMinionsKilled redAvgLevel
# candidates left: 482  selected: blueWardsDestroyed blueExperienceDiff
# candidates left: 481  selected: blueExperienceDiff redWardsDestroyed
# candidates left: 480  selected: blueDragons redTowersDestroyed
# candidates left: 479  selected: blueDragons blueTowersDestroyed
# candidates left: 478  selected: blueTowersDestroyed redTowersDestroyed
# candidates left: 477  selected: blueTotalGold redExperienceDiff
# candidates left: 476  selected: blueWardsPlaced blueGoldDiff
# candidates left: 475  selected: blueDragons blueCSPerMin
# candidates left: 474  selected: blueWardsDestroyed redExperienceDiff
# candidates left: 473  selected: blueDragons redDragons
# candidates left: 472  selected: blueHeralds redHeralds
# candidates left: 471  selected: blueTotalJungleMinionsKilled redCSPerMin
# candidates left: 470  selected: blueAvgLevel blueGoldDiff
# candidates left: 469  selected: blueDeaths blueExperienceDiff
# candidates left: 468  selected: blueDeaths redExperienceDiff
# candidates left: 467  selected: redWardsDestroyed redExperienceDiff
# candidates left: 466  selected: blueHeralds redTowersDestroyed
# candidates left: 465  selected: redHeralds redTotalJungleMinionsKilled
# candidates left: 464  selected: blueDragons blueGoldDiff
# candidates left: 463  selected: blueTowersDestroyed^2
# candidates left: 462  selected: blueTowersDestroyed blueGoldDiff
# candidates left: 461  selected: blueGoldDiff redTotalGold
# candidates left: 460  selected: blueFirstBlood blueExperienceDiff
# candidates left: 459  selected: blueHeralds blueTowersDestroyed
# candidates left: 458  selected: blueDeaths redHeralds
# candidates left: 457  selected: blueFirstBlood redExperienceDiff
# candidates left: 456  selected: blueTowersDestroyed redWardsDestroyed
# candidates left: 455  selected: blueHeralds redWardsDestroyed
# candidates left: 454  selected: blueTowersDestroyed redDragons
# candidates left: 453  selected: redTotalJungleMinionsKilled
# candidates left: 452  selected: blueAvgLevel
# candidates left: 451  selected: blueGoldDiff redWardsPlaced
# candidates left: 450  selected: blueDeaths redWardsPlaced
# candidates left: 449  selected: redWardsPlaced redTotalGold
# candidates left: 448  selected: blueDragons blueExperienceDiff
# candidates left: 447  selected: redWardsPlaced
# candidates left: 446  selected: blueTowersDestroyed redTotalMinionsKilled
# candidates left: 445  selected: blueAvgLevel redWardsPlaced
# candidates left: 444  selected: blueDragons redExperienceDiff
# candidates left: 443  selected: blueTowersDestroyed redCSPerMin
# candidates left: 442  selected: blueTotalExperience redTotalMinionsKilled
# candidates left: 441  selected: blueExperienceDiff redWardsPlaced
# candidates left: 440  selected: blueAssists redDragons
# candidates left: 439  selected: blueWardsPlaced redTotalJungleMinionsKilled
# candidates left: 438  selected: blueHeralds redDragons
# candidates left: 437  selected: blueTotalExperience redHeralds
# candidates left: 436  selected: blueTotalExperience redCSPerMin
# candidates left: 435  selected: redWardsPlaced redExperienceDiff
# candidates left: 434  selected: blueDragons redAssists
# candidates left: 433  selected: redWardsPlaced redAvgLevel
# candidates left: 432  selected: redWardsPlaced redTotalExperience
# candidates left: 431  selected: blueDragons redHeralds
# candidates left: 430  selected: blueGoldDiff redWardsDestroyed
# candidates left: 429  selected: redWardsPlaced redTotalJungleMinionsKilled
# candidates left: 428  selected: redAssists redHeralds
# candidates left: 427  selected: blueKills^2
# candidates left: 426  selected: blueTotalGold redHeralds
# candidates left: 425  selected: redAssists redTowersDestroyed
# candidates left: 424  selected: redHeralds
# candidates left: 423  selected: blueAvgLevel^2
# candidates left: 422  selected: redAvgLevel redTotalJungleMinionsKilled
# candidates left: 421  selected: redWardsPlaced redTotalMinionsKilled
# candidates left: 420  selected: redWardsDestroyed redTowersDestroyed
# candidates left: 419  selected: blueWardsPlaced blueTowersDestroyed
# candidates left: 418  selected: redWardsPlaced redCSPerMin
# candidates left: 417  selected: blueDeaths redTowersDestroyed
# candidates left: 416  selected: redHeralds^2
# candidates left: 415  selected: blueTotalJungleMinionsKilled redWardsDestroyed
# candidates left: 414  selected: blueKills redHeralds
# candidates left: 413  selected: redDragons redTotalJungleMinionsKilled
# candidates left: 412  selected: blueTowersDestroyed
# candidates left: 411  selected: blueTowersDestroyed blueTotalMinionsKilled
# candidates left: 410  selected: blueTowersDestroyed blueCSPerMin
# candidates left: 409  selected: blueWardsPlaced redTowersDestroyed
# candidates left: 408  selected: blueWardsPlaced blueTotalJungleMinionsKilled
# candidates left: 407  selected: blueAvgLevel redAvgLevel
# candidates left: 406  selected: blueAvgLevel redHeralds
# candidates left: 405  selected: blueTowersDestroyed blueTotalExperience
# candidates left: 404  selected: blueTowersDestroyed redTotalJungleMinionsKilled
# candidates left: 403  selected: blueTowersDestroyed redAvgLevel
# candidates left: 402  selected: blueFirstBlood blueTowersDestroyed
# candidates left: 401  selected: blueAssists redAssists
# candidates left: 400  selected: blueTowersDestroyed blueAvgLevel
# candidates left: 399  selected: blueTotalExperience redWardsPlaced
# candidates left: 398  selected: blueWardsPlaced blueExperienceDiff
# candidates left: 397  selected: blueWardsDestroyed blueTowersDestroyed
# candidates left: 396  selected: blueFirstBlood blueGoldDiff
# candidates left: 395  selected: blueWardsPlaced blueTotalExperience
# candidates left: 394  selected: blueTotalMinionsKilled redHeralds
# candidates left: 393  selected: blueWardsPlaced redAvgLevel
# candidates left: 392  selected: blueWardsPlaced redExperienceDiff
# candidates left: 391  selected: blueGoldDiff redTotalJungleMinionsKilled
# candidates left: 390  selected: redDragons redTotalExperience
# candidates left: 389  selected: redDragons redAvgLevel
# candidates left: 388  selected: blueWardsPlaced blueTotalGold
# candidates left: 387  selected: blueExperienceDiff redDragons
# candidates left: 386  selected: blueWardsPlaced redTotalGold
# candidates left: 385  selected: blueWardsPlaced blueDeaths
# candidates left: 384  selected: blueWardsPlaced redTotalExperience
# candidates left: 383  selected: blueTotalJungleMinionsKilled
# candidates left: 382  selected: redDragons redExperienceDiff
# candidates left: 381  selected: blueWardsPlaced redWardsPlaced
# candidates left: 380  selected: blueCSPerMin redHeralds
# candidates left: 379  selected: blueAvgLevel redTotalMinionsKilled
# candidates left: 378  selected: blueDragons redTotalJungleMinionsKilled
# candidates left: 377  selected: blueTotalGold blueTotalExperience
# candidates left: 376  selected: blueAvgLevel redDragons
# candidates left: 375  selected: redTowersDestroyed redTotalJungleMinionsKilled
# candidates left: 374  selected: redWardsPlaced redTowersDestroyed
# candidates left: 373  selected: redDragons redHeralds
# candidates left: 372  selected: blueAvgLevel redTotalJungleMinionsKilled
# candidates left: 371  selected: blueTowersDestroyed redTotalExperience
# candidates left: 370  selected: redTotalMinionsKilled^2
# candidates left: 369  selected: blueTotalExperience redDragons
# candidates left: 368  selected: redTotalGold
# candidates left: 367  selected: redTotalMinionsKilled redCSPerMin
# candidates left: 366  selected: blueWardsPlaced
# candidates left: 365  selected: blueWardsDestroyed
# candidates left: 364  selected: blueTotalGold redTotalExperience
# candidates left: 363  selected: redTotalMinionsKilled redTotalJungleMinionsKilled
# candidates left: 362  selected: redCSPerMin^2
# candidates left: 361  selected: blueAvgLevel blueTotalJungleMinionsKilled
# candidates left: 360  selected: redHeralds redTowersDestroyed
# candidates left: 359  selected: blueTotalJungleMinionsKilled redTotalGold
# candidates left: 358  selected: blueWardsPlaced blueAvgLevel
# candidates left: 357  selected: blueTotalMinionsKilled blueGoldDiff
# candidates left: 356  selected: redTotalJungleMinionsKilled redCSPerMin
# candidates left: 355  selected: blueGoldDiff redTotalExperience
# candidates left: 354  selected: blueExperienceDiff redAssists
# candidates left: 353  selected: blueDragons redTotalExperience
# candidates left: 352  selected: redTowersDestroyed redTotalMinionsKilled
# candidates left: 351  selected: blueWardsDestroyed redTowersDestroyed
# candidates left: 350  selected: blueWardsDestroyed redAvgLevel
# candidates left: 349  selected: redAvgLevel^2
# candidates left: 348  selected: redTowersDestroyed redCSPerMin
# candidates left: 347  selected: blueTotalExperience
# candidates left: 346  selected: blueWardsDestroyed blueAvgLevel
# candidates left: 345  selected: redAvgLevel redTotalMinionsKilled
# candidates left: 344  selected: blueDragons redAvgLevel
# candidates left: 343  selected: blueGoldDiff blueCSPerMin
# candidates left: 342  selected: blueAvgLevel redCSPerMin
# candidates left: 341  selected: blueTotalExperience redTowersDestroyed
# candidates left: 340  selected: blueTotalExperience^2
# candidates left: 339  selected: blueTotalExperience blueTotalJungleMinionsKilled
# candidates left: 338  selected: blueTotalGold redDragons
# candidates left: 337  selected: redAssists redExperienceDiff
# candidates left: 336  selected: blueTotalMinionsKilled redTowersDestroyed
# candidates left: 335  selected: redAvgLevel redCSPerMin
# candidates left: 334  selected: blueGoldDiff
# candidates left: 333  selected: redTowersDestroyed redTotalGold
# candidates left: 332  selected: blueGoldDiff redAvgLevel
# candidates left: 331  selected: blueDragons redWardsPlaced
# candidates left: 330  selected: blueWardsDestroyed redTotalExperience
# candidates left: 329  selected: redTotalMinionsKilled
# candidates left: 328  selected: blueKills redTowersDestroyed
# candidates left: 327  selected: blueTotalJungleMinionsKilled redTotalExperience
# candidates left: 326  selected: blueAvgLevel redTotalGold
# candidates left: 325  selected: redTotalGold redAvgLevel
# candidates left: 324  selected: blueDeaths blueTotalMinionsKilled
# candidates left: 323  selected: redTotalGold redTotalExperience
# candidates left: 322  selected: blueTotalGold blueAvgLevel
# candidates left: 321  selected: blueDeaths blueCSPerMin
# candidates left: 320  selected: blueTotalGold
# candidates left: 319  selected: blueDragons redTotalMinionsKilled
# candidates left: 318  selected: blueDragons blueAvgLevel
# candidates left: 317  selected: blueExperienceDiff^2
# candidates left: 316  selected: blueTotalExperience redTotalJungleMinionsKilled
# candidates left: 315  selected: blueHeralds blueGoldDiff
# candidates left: 314  selected: blueTotalExperience redAvgLevel
# candidates left: 313  selected: blueTowersDestroyed blueTotalJungleMinionsKilled
# candidates left: 312  selected: blueDragons blueTotalExperience
# candidates left: 311  selected: blueAssists redTowersDestroyed
# candidates left: 310  selected: blueTotalJungleMinionsKilled redTowersDestroyed
# candidates left: 309  selected: blueWardsDestroyed blueTotalJungleMinionsKilled
# candidates left: 308  selected: redTotalExperience redTotalJungleMinionsKilled
# candidates left: 307  selected: blueDragons redCSPerMin
# candidates left: 306  selected: blueWardsPlaced redHeralds
# candidates left: 305  selected: blueCSPerMin redTowersDestroyed
# candidates left: 304  selected: blueDragons blueTotalJungleMinionsKilled
# candidates left: 303  selected: blueExperienceDiff redAvgLevel
# candidates left: 302  selected: redAvgLevel
# candidates left: 301  selected: blueExperienceDiff redTotalExperience
# candidates left: 300  selected: blueWardsPlaced redTotalMinionsKilled
# candidates left: 299  selected: blueExperienceDiff redExperienceDiff
# candidates left: 298  selected: redDragons redTowersDestroyed
# candidates left: 297  selected: redTowersDestroyed
# candidates left: 296  selected: blueAvgLevel redTowersDestroyed
# candidates left: 295  selected: blueTotalExperience blueExperienceDiff
# candidates left: 294  selected: redTotalExperience redTotalMinionsKilled
# candidates left: 293  selected: redAvgLevel redTotalExperience
# candidates left: 292  selected: redTotalGold^2
# candidates left: 291  selected: redExperienceDiff^2
# candidates left: 290  selected: redCSPerMin
# candidates left: 289  selected: redDragons
# candidates left: 288  selected: blueDragons
# candidates left: 287  selected: blueTowersDestroyed blueTotalGold
# candidates left: 286  selected: redTotalExperience redExperienceDiff
# candidates left: 285  selected: blueTotalExperience redTotalGold
# candidates left: 284  selected: blueTotalExperience redExperienceDiff
# candidates left: 283  selected: blueDeaths^2
# candidates left: 282  selected: redTowersDestroyed^2
# candidates left: 281  selected: blueTotalGold^2
# candidates left: 280  selected: blueExperienceDiff redTotalGold
# candidates left: 279  selected: blueTowersDestroyed redAssists
# candidates left: 278  selected: redHeralds redTotalGold
# candidates left: 277  selected: blueKills blueTotalMinionsKilled
# candidates left: 276  selected: blueHeralds blueExperienceDiff
# candidates left: 275  selected: blueExperienceDiff
# candidates left: 274  selected: blueTowersDestroyed redTotalGold
# candidates left: 273  selected: redTotalGold redTotalJungleMinionsKilled
# candidates left: 272  selected: redExperienceDiff
# candidates left: 271  selected: redTotalExperience redCSPerMin
# candidates left: 270  selected: blueWardsDestroyed blueTotalExperience
# candidates left: 269  selected: blueWardsDestroyed blueGoldDiff
# candidates left: 268  selected: blueKills blueHeralds
# candidates left: 267  selected: blueTotalJungleMinionsKilled blueExperienceDiff
# candidates left: 266  selected: redAvgLevel redExperienceDiff
# candidates left: 265  selected: blueGoldDiff redTotalMinionsKilled
# candidates left: 264  selected: blueWardsPlaced redCSPerMin
# candidates left: 263  selected: blueTotalMinionsKilled redWardsPlaced
# candidates left: 262  selected: blueDeaths blueTowersDestroyed
# candidates left: 261  selected: blueDeaths blueGoldDiff
# candidates left: 260  selected: redWardsDestroyed^2
# candidates left: 259  selected: redWardsDestroyed redHeralds
# candidates left: 258  selected: blueWardsDestroyed redTotalJungleMinionsKilled
# candidates left: 257  selected: blueFirstBlood blueDragons
# candidates left: 256  selected: blueGoldDiff redCSPerMin
# candidates left: 255  selected: blueWardsDestroyed blueTotalMinionsKilled
# candidates left: 254  selected: redTotalGold redExperienceDiff
# candidates left: 253  selected: blueTotalGold redAvgLevel
# candidates left: 252  selected: blueDragons^2
# candidates left: 251  selected: blueTotalJungleMinionsKilled redTotalJungleMinionsKilled
# candidates left: 250  selected: redWardsPlaced redAssists
# candidates left: 249  selected: redTotalExperience^2
# candidates left: 248  selected: blueTotalGold blueGoldDiff
# candidates left: 247  selected: blueFirstBlood redTowersDestroyed
# candidates left: 246  selected: blueKills redWardsDestroyed
# candidates left: 245  selected: blueWardsDestroyed blueTotalGold
# candidates left: 244  selected: blueWardsDestroyed redTotalGold
# candidates left: 243  selected: redAssists^2
# candidates left: 242  selected: blueDeaths redAssists
# candidates left: 241  selected: blueWardsDestroyed blueCSPerMin
# candidates left: 240  selected: redWardsDestroyed redAssists
# candidates left: 239  selected: blueGoldDiff redTowersDestroyed
# candidates left: 238  selected: blueDeaths redWardsDestroyed
# candidates left: 237  selected: blueDeaths redDragons
# candidates left: 236  selected: blueWardsPlaced redWardsDestroyed
# candidates left: 235  selected: blueTotalMinionsKilled blueTotalJungleMinionsKilled
# candidates left: 234  selected: blueWardsDestroyed redTotalMinionsKilled
# candidates left: 233  selected: redTowersDestroyed redAvgLevel
# candidates left: 232  selected: blueHeralds redWardsPlaced
# candidates left: 231  selected: blueGoldDiff redAssists
# candidates left: 230  selected: blueExperienceDiff redTowersDestroyed
# candidates left: 229  selected: blueKills redWardsPlaced
# candidates left: 228  selected: blueTotalMinionsKilled^2
# candidates left: 227  selected: blueKills blueCSPerMin
# candidates left: 226  selected: blueTowersDestroyed redHeralds
# candidates left: 225  selected: redTowersDestroyed redExperienceDiff
# candidates left: 224  selected: redTotalExperience
# candidates left: 223  selected: blueTotalMinionsKilled
# candidates left: 222  selected: blueTotalMinionsKilled redWardsDestroyed
# candidates left: 221  selected: blueTotalExperience blueTotalMinionsKilled
# candidates left: 220  selected: blueWardsPlaced redDragons
# candidates left: 219  selected: blueKills redDragons
# candidates left: 218  selected: blueTotalJungleMinionsKilled redExperienceDiff
# candidates left: 217  selected: blueAvgLevel blueTotalExperience
# candidates left: 216  selected: blueCSPerMin redWardsDestroyed
# candidates left: 215  selected: blueTotalGold redTotalMinionsKilled
# candidates left: 214  selected: blueTotalExperience redWardsDestroyed
# candidates left: 213  selected: blueCSPerMin redWardsPlaced
# candidates left: 212  selected: blueKills
# candidates left: 211  selected: blueAvgLevel redWardsDestroyed
# candidates left: 210  selected: blueAvgLevel blueExperienceDiff
# candidates left: 209  selected: blueTotalGold redWardsDestroyed
# candidates left: 208  selected: blueAssists blueGoldDiff
# candidates left: 207  selected: blueTotalMinionsKilled redTotalJungleMinionsKilled
# candidates left: 206  selected: blueTotalMinionsKilled redAvgLevel
# candidates left: 205  selected: redTotalGold redTotalMinionsKilled
# candidates left: 204  selected: redTotalGold redCSPerMin
# candidates left: 203  selected: blueKills blueTotalGold
# candidates left: 202  selected: blueTotalGold redCSPerMin
# candidates left: 201  selected: redDragons^2
# candidates left: 200  selected: blueTotalMinionsKilled redDragons
# candidates left: 199  selected: blueKills blueExperienceDiff
# candidates left: 198  selected: blueAvgLevel redExperienceDiff
# candidates left: 197  selected: blueKills redCSPerMin
# candidates left: 196  selected: redDragons redTotalGold
# candidates left: 195  selected: blueWardsDestroyed redWardsDestroyed
# candidates left: 194  selected: blueTotalGold redTowersDestroyed
# candidates left: 193  selected: blueTotalMinionsKilled blueExperienceDiff
# candidates left: 192  selected: blueCSPerMin redTotalJungleMinionsKilled
# candidates left: 191  selected: blueKills redAvgLevel
# candidates left: 190  selected: redHeralds redAvgLevel
# candidates left: 189  selected: blueKills redTotalExperience
# candidates left: 188  selected: blueWardsPlaced blueWardsDestroyed
# candidates left: 187  selected: blueAssists blueHeralds
# candidates left: 186  selected: blueWardsDestroyed redCSPerMin
# candidates left: 185  selected: blueTotalMinionsKilled blueCSPerMin
# candidates left: 184  selected: blueCSPerMin^2
# candidates left: 183  selected: blueKills redTotalJungleMinionsKilled
# candidates left: 182  selected: blueAvgLevel blueTotalMinionsKilled
# candidates left: 181  selected: blueDeaths redTotalMinionsKilled
# candidates left: 180  selected: blueKills redTotalGold
# candidates left: 179  selected: blueDeaths redTotalJungleMinionsKilled
# candidates left: 178  selected: blueWardsDestroyed blueDeaths
# candidates left: 177  selected: blueKills blueGoldDiff
# candidates left: 176  selected: blueTotalJungleMinionsKilled blueCSPerMin
# candidates left: 175  selected: blueDeaths blueTotalGold
# candidates left: 174  selected: redWardsDestroyed redTotalExperience
# candidates left: 173  selected: blueDeaths blueDragons
# candidates left: 172  selected: blueTotalMinionsKilled redTotalExperience
# candidates left: 171  selected: blueWardsDestroyed blueHeralds
# candidates left: 170  selected: blueHeralds redTotalExperience
# candidates left: 169  selected: redTowersDestroyed redTotalExperience
# candidates left: 168  selected: blueHeralds blueAvgLevel
# candidates left: 167  selected: blueWardsDestroyed redDragons
# candidates left: 166  selected: blueDeaths blueTotalExperience
# candidates left: 165  selected: blueHeralds redTotalGold
# candidates left: 164  selected: blueFirstBlood redWardsDestroyed
# candidates left: 163  selected: blueAvgLevel redTotalExperience
# candidates left: 162  selected: blueDragons redTotalGold
# candidates left: 161  selected: redHeralds redTotalExperience
# candidates left: 160  selected: blueHeralds blueTotalMinionsKilled
# candidates left: 159  selected: redWardsDestroyed redTotalJungleMinionsKilled
# candidates left: 158  selected: blueCSPerMin redTotalExperience
# candidates left: 157  selected: blueKills blueTotalJungleMinionsKilled
# candidates left: 156  selected: blueTotalMinionsKilled redTotalGold
# candidates left: 155  selected: blueTotalGold blueTotalMinionsKilled
# candidates left: 154  selected: blueCSPerMin redAvgLevel
# candidates left: 153  selected: blueKills blueDeaths
# candidates left: 152  selected: blueCSPerMin redTotalGold
# candidates left: 151  selected: blueHeralds redAvgLevel
# candidates left: 150  selected: blueAssists^2
# candidates left: 149  selected: blueGoldDiff blueExperienceDiff
# candidates left: 148  selected: blueWardsDestroyed blueKills
# candidates left: 147  selected: blueTotalGold redTotalGold
# candidates left: 146  selected: blueHeralds blueTotalExperience
# candidates left: 145  selected: blueDeaths
# candidates left: 144  selected: blueKills blueAvgLevel
# candidates left: 143  selected: blueTotalGold blueCSPerMin
# candidates left: 142  selected: blueCSPerMin
# candidates left: 141  selected: blueDeaths redTotalGold
# candidates left: 140  selected: blueWardsDestroyed blueDragons
# candidates left: 139  selected: blueKills blueTowersDestroyed
# candidates left: 138  selected: blueTotalExperience redTotalExperience
# candidates left: 137  selected: blueTotalGold redTotalJungleMinionsKilled
# candidates left: 136  selected: blueFirstBlood blueAssists
# candidates left: 135  selected: blueExperienceDiff redTotalJungleMinionsKilled
# candidates left: 134  selected: redWardsDestroyed
# candidates left: 133  selected: blueHeralds redTotalJungleMinionsKilled
# candidates left: 132  selected: blueKills blueAssists
# candidates left: 131  selected: blueDeaths redTotalExperience
# candidates left: 130  selected: blueWardsDestroyed redWardsPlaced
# candidates left: 129  selected: blueDeaths blueTotalJungleMinionsKilled
# candidates left: 128  selected: redWardsDestroyed redAvgLevel
# candidates left: 127  selected: blueAssists redWardsDestroyed
# candidates left: 126  selected: blueTotalJungleMinionsKilled blueGoldDiff
# candidates left: 125  selected: redTotalJungleMinionsKilled redExperienceDiff
# candidates left: 124  selected: blueHeralds
# candidates left: 123  selected: blueAvgLevel blueCSPerMin
# candidates left: 122  selected: blueTowersDestroyed blueExperienceDiff
# candidates left: 121  selected: redWardsDestroyed redTotalGold
# candidates left: 120  selected: blueCSPerMin redDragons
# candidates left: 119  selected: blueDragons blueTotalGold
# candidates left: 118  selected: blueTotalExperience blueCSPerMin
# candidates left: 117  selected: blueExperienceDiff redTotalMinionsKilled
# candidates left: 116  selected: blueWardsPlaced blueAssists
# candidates left: 115  selected: blueTowersDestroyed redExperienceDiff
# candidates left: 114  selected: blueHeralds blueCSPerMin
# candidates left: 113  selected: blueWardsDestroyed blueAssists
# candidates left: 112  selected: blueHeralds blueTotalGold
# candidates left: 111  selected: redWardsDestroyed redTotalMinionsKilled
# candidates left: 110  selected: redDragons redTotalMinionsKilled
# candidates left: 109  selected: blueAssists blueTowersDestroyed
# candidates left: 108  selected: blueTotalJungleMinionsKilled redWardsPlaced
# candidates left: 107  selected: blueDeaths redAvgLevel
# candidates left: 106  selected: blueWardsPlaced blueHeralds
# candidates left: 105  selected: blueDeaths redCSPerMin
# candidates left: 104  selected: blueKills blueDragons
# candidates left: 103  selected: redHeralds redTotalMinionsKilled
# candidates left: 102  selected: blueGoldDiff redDragons
# candidates left: 101  selected: blueTowersDestroyed redWardsPlaced
# candidates left: 100  selected: redWardsDestroyed redCSPerMin
# candidates left: 99  selected: blueKills redTotalMinionsKilled
# candidates left: 98  selected: blueWardsPlaced blueKills
# candidates left: 97  selected: blueFirstBlood blueHeralds
# candidates left: 96  selected: blueTotalJungleMinionsKilled^2
# candidates left: 95  selected: blueWardsDestroyed^2
# candidates left: 94  selected: blueExperienceDiff redCSPerMin
# candidates left: 93  selected: blueHeralds redExperienceDiff
# candidates left: 92  selected: redTotalMinionsKilled redExperienceDiff
# candidates left: 91  selected: blueTotalGold blueTotalJungleMinionsKilled
# candidates left: 90  selected: blueDeaths blueAvgLevel
# candidates left: 89  selected: redHeralds redCSPerMin
# candidates left: 88  selected: blueFirstBlood blueDeaths
# candidates left: 87  selected: redWardsPlaced^2
# candidates left: 86  selected: blueWardsPlaced blueTotalMinionsKilled
# candidates left: 85  selected: redWardsPlaced redWardsDestroyed
# candidates left: 84  selected: blueFirstBlood redTotalExperience
# candidates left: 83  selected: blueFirstBlood redAssists
# candidates left: 82  selected: redWardsDestroyed redDragons
# candidates left: 81  selected: blueHeralds redTotalMinionsKilled
# candidates left: 80  selected: blueFirstBlood blueKills
# candidates left: 79  selected: blueWardsPlaced blueCSPerMin
# candidates left: 78  selected: blueHeralds redCSPerMin
# candidates left: 77  selected: blueHeralds^2
# candidates left: 76  selected: blueWardsDestroyed blueFirstBlood
# candidates left: 75  selected: blueFirstBlood redTotalJungleMinionsKilled
# candidates left: 74  selected: blueFirstBlood blueTotalGold
# candidates left: 73  selected: blueAssists blueDragons
# candidates left: 72  selected: redWardsPlaced redHeralds
# candidates left: 71  selected: blueDragons redWardsDestroyed
# candidates left: 70  selected: blueKills blueTotalExperience
# candidates left: 69  selected: blueTotalMinionsKilled redAssists
# candidates left: 68  selected: blueTotalMinionsKilled redExperienceDiff
# candidates left: 67  selected: redAssists redAvgLevel
# candidates left: 66  selected: blueTotalGold redAssists
# candidates left: 65  selected: redAssists
# candidates left: 64  selected: blueGoldDiff^2
# candidates left: 63  selected: blueGoldDiff redExperienceDiff
# candidates left: 62  selected: redAssists redDragons
# candidates left: 61  selected: blueFirstBlood
# candidates left: 60  selected: redAssists redTotalMinionsKilled
# candidates left: 59  selected: blueTotalMinionsKilled redTotalMinionsKilled
# candidates left: 58  selected: redDragons redCSPerMin
# candidates left: 57  selected: blueAvgLevel redAssists
# candidates left: 56  selected: blueTotalExperience redAssists
# candidates left: 55  selected: redWardsPlaced redDragons
# candidates left: 54  selected: redAssists redTotalJungleMinionsKilled
# candidates left: 53  selected: blueFirstBlood redTotalMinionsKilled
# candidates left: 52  selected: blueFirstBlood redCSPerMin
# candidates left: 51  selected: blueKills redExperienceDiff
# candidates left: 50  selected: blueTotalJungleMinionsKilled redAssists
# candidates left: 49  selected: blueTotalMinionsKilled redCSPerMin
# candidates left: 48  selected: blueFirstBlood^2
# candidates left: 47  selected: blueWardsPlaced blueFirstBlood
# candidates left: 46  selected: redAssists redTotalGold
# candidates left: 45

# %%
lgr.fit(Xe_train[model_opt], y_train)
R2_train = lgr.score(Xe_train[model_opt], y_train)
R2_test  = lgr.score(Xe_test[model_opt], y_test)
print('train R2', R2_train.round(3))
print(' test R2', R2_test.round(3))

# %%
# coefficients
coef = pd.Series(lgr.coef_, index = Xe_train[model_opt].columns)
print(coef.sort_values(ascending=False).head(10))
